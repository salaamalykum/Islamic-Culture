# %% [markdown]
# # Islamic Culture RAG Exploration
# A geek-style notebook to explore the `dataset.jsonl`.

# %%
import json
with open('../metadata/dataset.jsonl') as f:
    data = [json.loads(line) for line in f]
print(f'Loaded {len(data)} documents.')
